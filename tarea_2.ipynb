# %% [markdown]
# <a href="https://colab.research.google.com/github/christian-alexis/edd_1310_2021/blob/master/tarea_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("El archivo numeros.txt sin espacios:\n".title())
arch = open("numeros.txt" , 'rt')
data = 0
while (data != ''):
  data = arch.readline().replace(" ", "")
  
  
  print(data)
  
  
arch.close
# Out:
# El Archivo Numeros.Txt Sin Espacios:
#
# 1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10
#
# 2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2
#
# 3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93
#
# 4,46,8,1,6,2,10,37,84,4,5,9,10,2,6,31,1,1,8,4,20,33,23,18,45
#
# 55,3,2,29,58,83,9,17,1,43,20,93,31,46,43,77,8,44,45,17,62
#
# 6,74,13,44,18,45,11,93,2,1,1,1,25,1,42,18,22,44,52
#
# 7,88,93,6,54,2,8,1,41,86,79,33,48,9,32,63,18,7,33,2,1,16,11,7
#
# 8,0,22,17,30,6,2,12,47,37,34,85,47,33,2,6,8,4,5,29,30,42,77,2
#
# 9,2,3,4,1,1,3,6,7,7,8,9,5,1,3,4,9,10,12,3,1,5,6,22,11,0,2
#
# 1,0,2,55,9,3,55,23,1,6,9,4,5,3,3,2,1,3,8,1,6,10,0,1,5,1,3
# <function TextIOWrapper.close>

# %%
otro = open("numeros.txt" , 'rt')
datos = otro.read().replace(" ", "")
res = datos.split("\n")
f1= res[0].split(",")
tamaño=(len(res[0]))
print("Los lementos de la fila uno son:")
print(len(f1))
print("estos son:")
print(res[0])
print("La suma de estos es")

res1=(int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18])+ int (f1[19]))
print(res1)


f1= res[1].split(",")
tamaño=(len(res[1]))
print("Los lementos de la fila dos son:")
print(len(f1))
print("estos son:")
print(res[1])
print("La suma de estos es")

res2= (int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18]))

print(res2)



f1= res[2].split(",")
tamaño=(len(res[2]))
print("Los lementos de la fila tres son:")
print(len(f1))
print("estos son:")
print(res[2])
print("La suma de estos es")

res3= (int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18])+ int (f1[19])+int (f1[20]))
print(res3)



f1= res[3].split(",")
tamaño=(len(res[3]))
print("Los lementos de la fila cuatro son:".title())
print(len(f1))
print("estos son:".title())
print(res[3])
print("La suma de estos es".title())

res4= (int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18])+ int (f1[19])+int (f1[20])+ int (f1[21])+ int (f1[22])+
      int (f1[23])+ int (f1[24]))

print(res4)


f1= res[4].split(",")
tamaño=(len(res[4]))
print("Los lementos de la fila cinco son:")
print(len(f1))
print("estos son:")
print(res[4])
print("La suma de estos es")


res5= (int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18])+ int (f1[19])+int (f1[20]))

print(res5)



f1= res[5].split(",")
tamaño=(len(res[5]))
print("Los lementos de la fila seis son:")
print(len(f1))
print("estos son:")
print(res[5])
print("La suma de estos es")


res6= (int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18]))


print(res6)



f1= res[6].split(",")
tamaño=(len(res[6]))
print("Los lementos de la fila siete son:")
print(len(f1))
print("estos son:")
print(res[6])
print("La suma de estos es")



res7=(int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18])+ int (f1[19])+int (f1[20])+ int (f1[21])+ int (f1[22])+
      int (f1[23]))
print(res7)


f1= res[7].split(",")
tamaño=(len(res[7]))
print("Los lementos de la fila ocho son:")
print(len(f1))
print("estos son:")
print(res[7])
print("La suma de estos es")

res8=(int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+ int (f1[17])+
      int (f1[18])+ int (f1[19])+int (f1[20])+ int (f1[21])+ int (f1[22])+
      int (f1[23]))
print(res8)


f1= res[8].split(",")
tamaño=(len(res[8]))
print("Los lementos de la fila nueve son:")
print(len(f1))
print("estos son:")
print(res[8])
print("La suma de estos es\n")


res9=(int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+
      int (f1[17])+ int (f1[18])+ int (f1[19])+int (f1[20])+ int (f1[21])+
      int (f1[22])+int (f1[23])+ int (f1[24])+int (f1[25])+ int (f1[26]))
print(res9)




f1= res[8].split(",")
tamaño=(len(res[9]))
print("Los lementos de la fila diez son:")
print(len(f1))
print("estos son:")
print(res[9])
print("La suma de estos es\n")


res10=(int (f1[0])+ int (f1[1])+ int (f1[2])+ int (f1[3])+ int (f1[4])+ int (f1[5]) + 
      int (f1[6])+ int (f1[7])+ int (f1[8]) +int (f1[9])+ int (f1[10])+ int (f1[11])+
      int (f1[12])+ int (f1[13])+ int (f1[14])+ int (f1[15])+ int (f1[16])+
      int (f1[17])+ int (f1[18])+ int (f1[19])+int (f1[20])+ int (f1[21])+
      int (f1[22])+int (f1[23])+ int (f1[24])+int (f1[25])+ int (f1[26]))
print(res10)



print("\nLa suma de todos los elementos que hay en la lista es........".title())
 

print(res1 + res2 + res3 +res4 + res5 + res6 + res7 + res8 + res9 + res10)
# Out:
# Los lementos de la fila uno son:
# 20
# estos son:
# 1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10
# La suma de estos es
# 406
# Los lementos de la fila dos son:
# 19
# estos son:
# 2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2
# La suma de estos es
# 367
# Los lementos de la fila tres son:
# 21
# estos son:
# 3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93
# La suma de estos es
# 814
# Los Lementos De La Fila Cuatro Son:
# 25
# Estos Son:
# 4,46,8,1,6,2,10,37,84,4,5,9,10,2,6,31,1,1,8,4,20,33,23,18,45
# La Suma De Estos Es
# 418
# Los lementos de la fila cinco son:
# 21
# estos son:
# 55,3,2,29,58,83,9,17,1,43,20,93,31,46,43,77,8,44,45,17,62
# La suma de estos es
# 786
# Los lementos de la fila seis son:
# 19
# estos son:
# 6,74,13,44,18,45,11,93,2,1,1,1,25,1,42,18,22,44,52
# La suma de estos es
# 513
# Los lementos de la fila siete son:
# 24
# estos son:
# 7,88,93,6,54,2,8,1,41,86,79,33,48,9,32,63,18,7,33,2,1,16,11,7
# La suma de estos es
# 745
# ...
